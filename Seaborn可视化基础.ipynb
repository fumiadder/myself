# %% [markdown]
# ## Seaborn可视化基础
# ---
#
# - Matplotlib是高度可定制的，但快速实施出吸引人的细节就变得有些复杂。
# - Seaborn作为一个带着定制主题和高级界面控制的Matplotlib扩展包，能让绘图变得更轻松

# %% [markdown]
# ### 一、图表控制
#
# 了解seaborn如何对matplotlib输出的外观进行控制

# %% [markdown]
# 导包

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# 定义一个正弦函数，比较seaborn绘图和matplotlib绘图背景的区别

# %%
x = np.linspace(0, 2*np.pi, 100)

y = np.sin(x)

plt.plot(x, y)

# %%
def show_lines(x):
    for i in range(7):
        y = np.sin(x+i*0.5)
        plt.plot(x, y)

# %%
# 默认的matplotlib样式
show_lines(x)

# %%
plt.rcParams['axes.facecolor'] = 'white'

# %%
show_lines(x)

# %% [markdown]
# 使用sns.set()来设置seaborn默认的画布风格

# %%
# 全局配置
sns.set()

# %%
show_lines(x)
plt.title('sin x')
# Out:
# Text(0.5, 1.0, 'sin x')

# %% [markdown]
# #### 样式控制：
#
# 1. axes_style:获取设置背景样式的属性字典
# 2. set_style(style, rc):设置背景样式
#
#
# style可选的5个seaborn默认主题
# - darkgrid 黑色网格（默认）
# - whitegrid 白色网格
# - dark 黑色背景
# - white 白色背景
# - ticks 有刻度线的白背景
#
# - rc 背景样式的属性字典设置接口

# %% [markdown]
# sns.axes_style()函数可以返回可以设置的属性字典

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
# 全局配置 画布风格
sns.set_style(style='darkgrid', rc={
    'axes.facecolor':'#EAEAF2'
})

# %%
show_lines(x)

# %%
# 临时配置
with sns.axes_style(style='ticks'):
    show_lines(x)

# %% [markdown]
# #### 边框控制 despine()
#
# - 默认删除上方和右方的边框
# - offset 两坐标轴分开的距离
# - trim True False限制留存的边框范围,没有图像的地方会舍弃
# - top right bottom left （True\False）指定是否删除对应的边框
# - **注意**边框控制的代码应放在绘图之后

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style(style='darkgrid', rc={
    'axes.edgecolor':'black',
    'axes.spines.left':False
})

# %%
show_lines(x)

# %%
show_lines(x)
plt.axis('equal')

# despine要在绘图函数后生效，设置为True，即为隐藏对应的边框
sns.despine(left=False, top=False, right=False, bottom=False, offset=10, trim=5)

# %% [markdown]
# #### 临时设定图形样式
#
# ```
# sns.set_style()是全局性的设置，如果希望单独对某一个图像进行临时设置，可以使用**with**语句
#
# with sns.axes_style():
# ```

# %% [markdown]
# #### 通过plotting_context() 和 set_context() 调整绘图元素

# %% [markdown]
# - sns.set()可以重置所有设置
#
# - 四种预设，按相对尺寸的顺序(线条越来越粗)，分别是paper，notebook, talk, and poster。notebook的样式是默认的。
#
# - sns.plotting_context() 可以获取所有默认设置的属性字典

# %%
axes_style  画布风格配置
context  线条配置
palette  调色板

# %%
sns.plotting_context()
# Out:
# {'font.size': 12.0,
#  'axes.labelsize': 12.0,
#  'axes.titlesize': 12.0,
#  'xtick.labelsize': 11.0,
#  'ytick.labelsize': 11.0,
#  'legend.fontsize': 11.0,
#  'axes.linewidth': 1.25,
#  'grid.linewidth': 1.0,
#  'lines.linewidth': 1.5,
#  'lines.markersize': 6.0,
#  'patch.linewidth': 1.0,
#  'xtick.major.width': 1.25,
#  'ytick.major.width': 1.25,
#  'xtick.minor.width': 1.0,
#  'ytick.minor.width': 1.0,
#  'xtick.major.size': 6.0,
#  'ytick.major.size': 6.0,
#  'xtick.minor.size': 4.0,
#  'ytick.minor.size': 4.0,
#  'legend.title_fontsize': 12.0}

# %% [markdown]
# 1.使用默认值设置线条粗细

# %%
sns.set()

# %% [markdown]
# 2.使用字典控制绘图元素

# %%
# 对context做全局的配置修改
sns.set_context(context='poster', rc={
    'axes.labelsize':12.0,
    'xtick.labelsize': 12.0,
     'ytick.labelsize': 12.0,
})

# %%
# 获取当前context设置属性值
sns.plotting_context()
# Out:
# {'font.size': 24.0,
#  'axes.labelsize': 12.0,
#  'axes.titlesize': 24.0,
#  'xtick.labelsize': 12.0,
#  'ytick.labelsize': 12.0,
#  'legend.fontsize': 22.0,
#  'axes.linewidth': 2.5,
#  'grid.linewidth': 2.0,
#  'lines.linewidth': 3.0,
#  'lines.markersize': 12.0,
#  'patch.linewidth': 2.0,
#  'xtick.major.width': 2.5,
#  'ytick.major.width': 2.5,
#  'xtick.minor.width': 2.0,
#  'ytick.minor.width': 2.0,
#  'xtick.major.size': 12.0,
#  'ytick.major.size': 12.0,
#  'xtick.minor.size': 8.0,
#  'ytick.minor.size': 8.0,
#  'legend.title_fontsize': 24.0}

# %%
show_lines(x)
plt.title('sin x')
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %% [markdown]
# 3. 临时配置

# %%
with sns.plotting_context(context='paper'):
    show_lines(x)

# %%
show_lines(x)

# %% [markdown]
# ### 二、调色板

# %% [markdown]
# #### 通过color_palette()创建调色板
#
# ```
# 最重要的直接设置调色板的函数就是color_palette()。这个函数提供了许多（并非所有）在seaborn内生成颜色的方式。并且它可以用于任何函数内部的palette参数设置
#
# color_palette()允许任意的seaborn调色板或matplotlib的颜色映射。它还可以使用任何有效的matplotlib格式指定的颜色列表(RGB元组、十六进制颜色代码或HTML颜色名称)。返回值总是一个RGB元组的列表。
# ```

# %% [markdown]
# 1.查看默认主题deep的调色板颜色，使用sns.palplot()展示调色板颜色,默认颜色循环使用

# %%
np.random.randint(0, 2, size=10)
# Out:
# array([0, 1, 0, 1, 0, 1, 1, 1, 0, 0])

# %%
xdata
# Out:
# array([93, 61, 51, 58, 98, 57, 51, 21, 80, 57])

# %%
ydata
# Out:
# array([88, 64, 35, 13, 80, 44, 56, 73, 81,  6])

# %%
# 使用matplotlib定制调色板
from matplotlib.colors import ListedColormap

# %%
cmap = ListedColormap(colors=['red','blue'])

# %%
# matplotlib里面提供了很多默认的调色板
colors = plt.cm.Accent

# %%
xdata = np.random.randint(0, 100, size=10)
ydata = np.random.randint(0, 100, size=10)

cdata = np.random.randint(0, 2, size=10)

# cmap 是我们自定义的调色板
# plt.cm.Accent matplotlib系统预置的调色板（分类调色板）
plt.scatter(xdata, ydata, c=cdata, cmap=plt.cm.winter)

# %%
show_lines(x)

# %%
for i in range(7):
    plt.plot(x, np.sin(x+i*0.5), color='red')

# %%
# 使用color_palette获取颜色列表（调色板）
# deep, muted, bright, pastel, dark, colorblind
colors = sns.color_palette(palette='dark')

# %%
colors
# Out:
# [(0.0, 0.10980392156862745, 0.4980392156862745),
#  (0.6941176470588235, 0.25098039215686274, 0.050980392156862744),
#  (0.07058823529411765, 0.44313725490196076, 0.10980392156862745),
#  (0.5490196078431373, 0.03137254901960784, 0.0),
#  (0.34901960784313724, 0.11764705882352941, 0.44313725490196076),
#  (0.34901960784313724, 0.1843137254901961, 0.050980392156862744),
#  (0.6352941176470588, 0.20784313725490197, 0.5098039215686274),
#  (0.23529411764705882, 0.23529411764705882, 0.23529411764705882),
#  (0.7215686274509804, 0.5215686274509804, 0.0392156862745098),
#  (0.0, 0.38823529411764707, 0.4549019607843137)]

# %%
for i in range(7):
    plt.plot(x, np.sin(x+i*0.5), color=colors[i])

# %% [markdown]
# #### 分类调色板
# ```
# 分类色板（定性）是在区分没有固定顺序的数据时最好的选择, 类似matplotlib的标准颜色循环
#
# 默认颜色主题共有六种不同的变化分别是：deep, muted, pastel, bright, dark, 和 colorblind。类似下面的方式直接传入即可。
# ```

# %%
colors = sns.color_palette(palette='pastel', n_colors=20)
colors
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
# ...

# %%
data = np.array(np.random.randint(10, 30, size=12))
label = list('ABCDEFGHIJKL')

plt.bar(x=label, height=data, color=colors)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# #### 圆形调色板 (可以定制更多颜色的分类调色板）
# ```
# 你有十个以上的分类要区分时，最简单的方法就是在一个圆形的颜色空间中画出均匀间隔的颜色(这样的色调会保持亮度和饱和度不变)。这是大多数的当他们需要使用比当前默认颜色循环中设置的颜色更多时的默认方案。
# ```

# %% [markdown]
# 1.hls的颜色空间
# ```
# 是RGB值的一个简单转换
# sns.color_palette(palette="hls")
# ```

# %%
colors = sns.color_palette(palette='hls',n_colors=20)
colors
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.5272, 0.33999999999999997),
#  (0.86, 0.6832, 0.33999999999999997),
#  (0.86, 0.8392000000000002, 0.33999999999999997),
#  (0.7247999999999999, 0.86, 0.33999999999999997),
#  (0.5688000000000001, 0.86, 0.33999999999999997),
#  (0.41279999999999994, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.42320000000000013),
#  (0.33999999999999997, 0.86, 0.5792000000000002),
#  (0.33999999999999997, 0.86, 0.7352000000000001),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.6727999999999997, 0.86),
#  (0.33999999999999997, 0.5167999999999995, 0.86),
#  (0.33999999999999997, 0.36079999999999973, 0.86),
#  (0.4752000000000003, 0.33999999999999997, 0.86),
#  (0.6311999999999998, 0.33999999999999997, 0.86),
#  (0.7871999999999999, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.7767999999999993),
#  (0.86, 0.33999999999999997, 0.6207999999999999),
# ...

# %%
plt.bar(x=label, height=data, color=colors)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# 也可以使用hls_palette()函数来控制颜色的亮度和饱和。
# ```
#  l - 亮度 lightness
#  s - 饱和度 saturation
#  h - 控制起始颜色的值
# ```

# %%
sns.hls_palette(n_colors=10, h=0.2, l=0.4, s=0.6)
# Out:
# [(0.544, 0.6400000000000001, 0.15999999999999992),
#  (0.25599999999999995, 0.6400000000000001, 0.15999999999999992),
#  (0.15999999999999992, 0.6400000000000001, 0.35200000000000015),
#  (0.15999999999999992, 0.64, 0.6400000000000001),
#  (0.15999999999999992, 0.35199999999999965, 0.6400000000000001),
#  (0.2559999999999996, 0.15999999999999992, 0.6400000000000001),
#  (0.544, 0.15999999999999992, 0.6400000000000001),
#  (0.6400000000000001, 0.15999999999999992, 0.44799999999999934),
#  (0.6400000000000001, 0.15999999999999992, 0.15999999999999992),
#  (0.6400000000000001, 0.4480000000000003, 0.15999999999999992)]

# %% [markdown]
# 2.husl颜色
#
# ```
# 由于人类视觉系统的工作方式，会导致在RGB度量上强度一致的颜色在视觉中并不平衡。比如，我们黄色和绿色是相对较亮的颜色，而蓝色则相对较暗，使得这可能会成为与hls系统一致的一个问题。
#
# 为了解决这一问题，seaborn为husl系统提供了一个接口，这也使得选择均匀间隔的色彩变得更加容易，同时保持亮度和饱和度更加一致。
#
# sns.color_palette("husl")
# ```

# %%
sns.color_palette(palette='husl', n_colors=20)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.9704241569984234, 0.4603475375001678, 0.3099359864545268),
#  (0.8616090647292522, 0.536495730113334, 0.19548899031476086),
#  (0.7632105624545802, 0.5838460616396939, 0.19465686802007026),
#  (0.6804189127793346, 0.6151497514677574, 0.19405452111445337),
#  (0.5920891529639701, 0.6418467016378244, 0.1935069134991043),
#  (0.46810256823426105, 0.6699492535792404, 0.1928958739904499),
#  (0.19316929744982803, 0.7018418078239693, 0.24321388407365968),
#  (0.20125317221201128, 0.6907920815379025, 0.47966761189275336),
#  (0.20631516405196249, 0.6834948167725491, 0.5761817437653648),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.21461147568939787, 0.6708637556281021, 0.7042594890626992),
#  (0.2197995660828324, 0.6625157876850336, 0.7732093159317209),
#  (0.22829030785596155, 0.6480515334381642, 0.8744997507366618),
#  (0.433280341176423, 0.6065273407962815, 0.9585467098271748),
# ...

# %% [markdown]
# ```
# husl颜色也提供了一个可以自定义的函数 husl_palette()
# ```

# %%
colors = sns.husl_palette(n_colors=6)
colors
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.7350228985632719, 0.5952719904750953, 0.1944419133847522),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.23299120924703914, 0.639586552066035, 0.9260706093977744),
#  (0.9082572436765556, 0.40195790729656516, 0.9576909250290225)]

# %% [markdown]
# 3.使用choose_colorbrewer_palette()函数启动调色板小工具Color Brewer来挑选喜欢的颜色参数
# ```
# sequential  连续的   渐变色
# diverging   发散的   两极分化（表达两端的数据都需要被重视）
# qualitative 定性的   分类表示
#
# as_cmap 设置颜色范围是离散还是连续
# ```

# %%
ListedColormap(['red','green'])

# %%
# as_cmap=True, 就是把颜色列表，封装成cmap对象，供cmap参数使用
colors = sns.choose_colorbrewer_palette(data_type='diverging', as_cmap=True)
# Out:
# interactive(children=(Dropdown(description='name', options=('RdBu', 'RdGy', 'PRGn', 'PiYG', 'BrBG', 'RdYlBu', …

# %%
# 类似于print  palplot是展示颜色的函数
# 调色板工具的变化，会实时改变返回值
sns.palplot(colors)

# %% [markdown]
# 4.使用自定义颜色列表来自定制调色板
#
# ```
# colors = ["red","green","blue","yellow"]
# sns.color_palette(colors)
# ```

# %%
colors = ["red","green","blue","yellow"]
sns.color_palette(colors)
# Out:
# [(1.0, 0.0, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.0, 1.0), (1.0, 1.0, 0.0)]

# %% [markdown]
# #### 连续调色板
#
# ```
# 这种颜色映射对应的是从相对低价值（无意义）数据到高价值（有意义）的数据范围。
#
# 比如温度变化、海拔变化等。
#
# 对于连续的数据，最好是使用那些在色调上相对细微变化的调色板，同时在亮度和饱和度上有很大的变化。这种方法将自然地吸引数据中相对重要的部分
# ```

# %% [markdown]
# 1.Color Brewer字典中提供了一些连续调色板，如“Blues”，“BuGn_r”，“GnBu_d”,“PuBuGn_d”
#
# ```
# 颜色中带_r后缀的，表示颜色翻转渐变
# 颜色中带_d后缀的，表示对原颜色进行变暗处理
# ```

# %%
sns.color_palette(palette='PuBuGn_d')
# Out:
# [(0.5471741637831604, 0.7045751633986929, 0.8193156478277586),
#  (0.38405741381519937, 0.6400871459694989, 0.7639318210944509),
#  (0.2253492246571832, 0.5773420479302832, 0.7100448545431245),
#  (0.15194668717160065, 0.49502499038831216, 0.6123644752018454),
#  (0.16781750608740229, 0.3975855440215301, 0.4761707035755479),
#  (0.1841291810841984, 0.297439446366782, 0.3361937716262976)]

# %% [markdown]
# 2.cubehelix_palette()函数的连续调色板
# ```
# cubehelix调色板系统具有线性增加或降低亮度和色调变化顺序的调色板。这意味着在你的映射信息会在保存为黑色和白色（为印刷）时或被一个色盲的人浏览时可以得以保留。
#
# 1). Matplotlib拥有一个默认的内置cubehelix版本可供创建:
# sns.color_palette("cubehelix",8)
# ```

# %%
sns.color_palette(palette='cubehelix', n_colors=10)
# Out:
# [(0.09854228363950114, 0.07115215572295082, 0.16957891809124037),
#  (0.09159726558869188, 0.20394337960213008, 0.29623965888210324),
#  (0.09406611799930162, 0.3578871412608098, 0.2837709711722866),
#  (0.23627685553553793, 0.46114369021199075, 0.19770731888985724),
#  (0.49498740849493095, 0.4799034869159042, 0.21147789468974837),
#  (0.7354526513473981, 0.4748861903571046, 0.40254094042448907),
#  (0.8325928529853291, 0.5253446757844744, 0.6869376931865354),
#  (0.7936920632275369, 0.6641337211433709, 0.9042311843062529),
#  (0.7588424692372241, 0.8253990353420474, 0.9542699331220588),
#  (0.8385645211683802, 0.9411869386771845, 0.9357655639413166)]

# %%
sns.cubehelix_palette(n_colors=6, start=0.5)
# Out:
# [[0.8545017568606998, 0.8678299512500061, 0.7510012167751896],
#  [0.766337097923384, 0.7099163622133736, 0.5550190910125214],
#  [0.6880723598244912, 0.5362869497032949, 0.41633157154449335],
#  [0.5872733168282167, 0.37128908558376056, 0.32845539987631],
#  [0.4364872331399352, 0.22200256585911315, 0.2569866305608439],
#  [0.2373282836136655, 0.10134589881755829, 0.16388314593237166]]

# %% [markdown]
# ```
# 2). seaborn为cubehelix系统添加一个接口使得其可以在各种变化中都保持良好的亮度线性梯度。
#
# 通过seaborn的cubehelix_palette()函数返回的调色板与matplotlib默认值稍有所不同，它不会在色轮周围旋转或覆盖更广的强度范围。seaborn还改变了排序使得更重要的值显得更暗：
#
# 可以使用choose_cubehelix_palette调色板插件选择颜色
# ```

# %%
colors = sns.choose_cubehelix_palette()
# Out:
# interactive(children=(IntSlider(value=9, description='n_colors', max=16, min=2), FloatSlider(value=0.0, descri…

# %% [markdown]
# 3.使用light_palette() 和dark_palette()调用定制连续调色板
# ```
# 这里还有一个更简单的连续调色板的使用方式，就是调用light_palette() 和dark_palette()，这与一个单一颜色和种子产生的从亮到暗的饱和度的调色板。这些函数还伴有choose_light_palette() and choose_dark_palette()函数，这些函数启动了交互式小部件来创建这些调色板
# ```

# %% [markdown]
# ```
# 1). 使用html颜色设置调色板
# sns.dark_palette(color="green")
# ```

# %%
sns.dark_palette(color='purple')
# Out:
# [(0.16949189743051377, 0.13806689901726715, 0.16947713018450253),
#  (0.2359856748071561, 0.11045351921381372, 0.23597386101034712),
#  (0.30247945218379846, 0.08284013941036028, 0.30247059183619174),
#  (0.3689732295604408, 0.05522675960690686, 0.3689673226620363),
#  (0.4354670069370832, 0.027613379803453422, 0.435464053487881),
#  (0.5019607843137255, 0.0, 0.5019607843137255)]

# %% [markdown]
# ```
# 2). 把使用插件调整过颜色值保留下来
# dark = sns.choose_dark_palette(as_cmap=False)
# ```

# %%
sns.choose_dark_palette()
# Out:
# interactive(children=(IntSlider(value=179, description='h', max=359), IntSlider(value=49, description='s', max…
# [(0.14135330736111978, 0.14951274600325057, 0.1481436717094509),
#  (0.16219560832714164, 0.18641978556477623, 0.18281574337590473),
#  (0.1830379092931635, 0.22332682512630186, 0.2174878150423586),
#  (0.204624578150829, 0.2615519732435963, 0.25339817498261435),
#  (0.22546687911685087, 0.29845901280512194, 0.2880702466490682),
#  (0.24705354797451634, 0.3366841609224164, 0.323980606589324),
#  (0.2678958489405382, 0.373591200483942, 0.35865267825577785),
#  (0.2894825177982037, 0.4118163486012364, 0.3945630381960336),
#  (0.3103248187642256, 0.448723388162762, 0.4292351098624875),
#  (0.33116711973024743, 0.4856304277242877, 0.46390718152894134)]

# %%
sns.choose_light_palette()
# Out:
# interactive(children=(IntSlider(value=179, description='h', max=359), IntSlider(value=49, description='s', max…
# [(0.928400678190116, 0.9478103788759907, 0.944453036504835),
#  (0.8628220913788363, 0.8970612077691371, 0.8916872171349329),
#  (0.7972435045675565, 0.8463120366622834, 0.8389213977650309),
#  (0.7293228253701598, 0.7937503951587563, 0.7842710848462038),
#  (0.6637442385588801, 0.7430012240519027, 0.7315052654763018),
#  (0.5958235593614833, 0.6904395825483758, 0.6768549525574746),
#  (0.5302449725502036, 0.639690411441522, 0.6240891331875726),
#  (0.46232429335280684, 0.587128769937995, 0.5694388202687455),
#  (0.3967457065415272, 0.5363795988311414, 0.5166730008988434),
#  (0.33116711973024743, 0.4856304277242877, 0.46390718152894134)]

# %% [markdown]
# ```
# 3). 使用连续值来映射颜色
#
# cmap = sns.light_palette("blue", as_cmap=True)
# ```

# %%
sns.light_palette('purple', )
# Out:
# [(0.9520620893501853, 0.9400497244820778, 0.9519714734001828),
#  (0.8620418283428933, 0.7520397795856623, 0.8619693355828913),
#  (0.7720215673356013, 0.5640298346892467, 0.7719671977655999),
#  (0.6820013063283095, 0.3760198897928312, 0.6819650599483085),
#  (0.5919810453210175, 0.18800994489641554, 0.591962922131017),
#  (0.5019607843137255, 0.0, 0.5019607843137255)]

# %% [markdown]
# #### 离散调色板(发散）
# ```
# 用于可能无论大的低的值和大的高的值都非常重要的数据。数据中通常有一个定义良好的中点。例如，如果你正在绘制温度变化从基线值，最好使用不同色图显示相对降低和相对增加面积的地区。
#
# 选择离散色板的规则类似于顺序色板，除了你想满足一个强调的颜色中点以及用不同起始颜色的两个相对微妙的变化。同样重要的是，起始值的亮度和饱和度是相同的。
#
# 同样重要的是要强调，应该避免使用红色和绿色，因为大量的潜在观众将无法分辨它们。
# ```

# %%
cmap = sns.choose_colorbrewer_palette(data_type='diverging', as_cmap=True)
# Out:
# interactive(children=(Dropdown(description='name', options=('RdBu', 'RdGy', 'PRGn', 'PiYG', 'BrBG', 'RdYlBu', …

# %%
sns.heatmap(np.random.randint(-100, 100, size=(10, 10)), cmap=sns.color_palette('coolwarm', as_cmap=True), vmin=-100, vmax=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# sns.color_palette(palette=)

# %% [markdown]
# 1.Color Brewer颜色字典里的颜色映射值，例如BrBG、RdBu_r等

# %%
sns.color_palette(palette='RdBu_r')
# Out:
# [(0.18431372549019615, 0.4726643598615917, 0.7116493656286045),
#  (0.5300269127258748, 0.7456362937331797, 0.8560553633217993),
#  (0.8605151864667436, 0.9174163783160324, 0.9487120338331411),
#  (0.9856978085351789, 0.8889657823913879, 0.8320645905420991),
#  (0.9407151095732411, 0.609919261822376, 0.481276432141484),
#  (0.7561707035755478, 0.21038062283737025, 0.22352941176470587)]

# %% [markdown]
# 2.matplotlib中建立的明智的选择是coolwarm面板。
#
# ```sns.color_palette("coolwarm")```
#
# **注意** 这个颜色映射在中间值和极端之间并没有太大的对比。

# %%
sns.color_palette('coolwarm')
# Out:
# [(0.4044212904941176, 0.5346434904470588, 0.9320019126352941),
#  (0.603162067917647, 0.7315274773529412, 0.9995652785372549),
#  (0.7867207013568628, 0.8448072103686275, 0.9398103849490196),
#  (0.9306685963333333, 0.818876999654902, 0.7591463906980392),
#  (0.9673165156666667, 0.6574708288078431, 0.5381601507294118),
#  (0.8846434386941177, 0.41001709788235297, 0.32250654924705885)]

# %% [markdown]
# 3.用diverging_palette()使用定制离散色板
# ```
# 也可以使用海运功能diverging_palette()为离散的数据创建一个定制的颜色映射。（也有一个类似配套的互动工具：choose_diverging_palette()）。该函数使用husl颜色系统的离散色板。你需随意传递两种颜色，并设定明度和饱和度的端点。函数将使用husl的端点值及由此产生的中间值进行均衡
# ```

# %%
sns.diverging_palette()

# %% [markdown]
# ```
# 1). 使用互动工具获取颜色
# diverging = sns.choose_diverging_palette()
# ```

# %%
sns.choose_diverging_palette()
# Out:
# interactive(children=(IntSlider(value=220, description='h_neg', max=359), IntSlider(value=10, description='h_p…
# [(0.2519971417644415, 0.4987337088076726, 0.5751602783606602),
#  (0.43156001218774975, 0.6160490836499025, 0.6735874169971766),
#  (0.611122882611058, 0.7333644584921324, 0.7720145556336929),
#  (0.7906857530343663, 0.8506798333343624, 0.8704416942702093),
#  (0.95, 0.95, 0.95),
#  (0.9282549678814984, 0.7863704363662967, 0.7963965173228867),
#  (0.9022582584936525, 0.6005186021022944, 0.622400049291663),
#  (0.8762615491058064, 0.4146667678382919, 0.44840358126043944),
#  (0.8510408608937171, 0.23436274952246883, 0.2796010376480583)]

# %% [markdown]
# ```
# 2). 绘制颜色
# ```

# %% [markdown]
# 4.用set_palette()更改色变的默认值
#
# ```
# color_palette() 函数有一个名为set_palette()的配套。
#
# set_palette()接受与color_palette()相同的参数，但是它会更改默认的matplotlib参数，以便成为所有的调色板配置。
#
# sns.set_palette("husl")
# ```

# %%
# context
# axes_style
# palette

sns.set()

# %%
sns.set_palette(palette='husl')

# %%
for i in range(8):
    plt.plot(x, np.sin(x+i))

# %% [markdown]
# #### 简单常用色彩总结：
#
# - 分类：hls husl Paired Set1~Set3（色调不同）
# - 连续：Blues[蓝s，颜色+s] BuGn[蓝绿] cubehelix（同色系渐变）
# - 离散：BrBG[棕绿] RdBu[红蓝] coolwarm[冷暖]（双色对称）

# %%
sns.color_palette(palette='hls')
